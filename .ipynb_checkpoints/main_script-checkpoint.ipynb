# %%
import os
import sys
import pandas as pd
import numpy as np
import cv2
import argparse
import os
#from google.cloud import automl_v1beta1 as automl

# %%
from datetime import datetime

# %%
#setting up the path where I am storing my labeled videos, careful about  the slash (/)
project_path = "G:\\waste management\\inpid_files\\video_files\\"
data_images_Extracted = "G:\\waste management\\inpid_files\\images"
bucket_name = "edge_device"
#home_folder = os.path.expanduser('~')
#os.chdir(os.path.join(home_folder, project_path))
# home = os.environ['HOME'] , I think this is for linux.
#os.getcwd() --> This is to check the working directory

# %%
#here we check the files in our path, we would read the video files and change them into images
labels=[]
video_extract_path=project_path+'/'+''
file = os.listdir(video_extract_path)
for _ in file:
    labels.append(_.split('.')[0])

# %%
#Now we extract the images from the video
# Read the video from specified path 
try: 
    # creating a folder 
    if not os.path.exists(data_images_Extracted): 
        os.makedirs(data_images_Extracted)

# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of data')
      
data_array = []

for label in labels:
    subdirpath = data_images_Extracted + "/" + label
    try: 
        # creating a folder 
        if not os.path.exists(subdirpath): 
            os.makedirs(subdirpath)

    # if not created then raise error 
    except OSError: 
        print ('Error: Creating sub-directory of data')
       
    data_filename = label + ".mp4"
    
    print(data_filename)
    cam = cv2.VideoCapture( project_path + data_filename)
    currentframe = 0
    
    while(True): 
        ret,frame = cam.read() 
        if ret: 
            # if video is still left continue creating images 
            now = datetime.now()
            current_time = now.strftime("%H_%M_%S")
            object_name = data_images_Extracted+ "/" + label + "/" +label + "_frame" + str(currentframe)+"_" +current_time +'.jpg'

            cv2.imwrite(object_name, frame) 

            #upload to google storage - This will be done later due to high data requirement
#             upload(src_name = object_name, dst_name = object_name)
# The CSV file will be created in a different way.
#             gcs_path = 'gs://' + bucket_name + "/" + object_name 
#             data_array.append((gcs_path, label))

            # increasing counter so that it will 
            # show how many frames are created 
            currentframe += 1
        else:
            
            break

# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# aachi_sambar_powder.mp4
# amul_butter.mp4
# amul_rasin_and_almond.mp4
# banana_chips.mp4

# %%
labels
# Out:
# ['aachi_sambar_powder',
#  'amul_butter',
#  'amul_rasin_and_almond',
#  'banana_chips',
#  'basmati_rice',
#  'bingo',
#  'britania_toast',
#  'cadbury_hot_chocolate',
#  'cadbury_hot_chocolate_2',
#  'cake_box',
#  'catch_hing',
#  'cat_toothpaste',
#  'chicken_nuggets',
#  'chings_schezwan',
#  'chings_veggie_twist',
#  'cleanmate',
#  'coffee_packet',
#  'complan',
#  'corn_packet',
#  'doublemint',
#  'dove',
#  'dove_derma_spa',
#  'dove_derma_spa_1',
#  'eastern_meat_masala',
#  'eastern_sambar_powder',
#  'eastern_super_garam_masala',
#  'ektaa_chidwa',
#  'elkos_body',
#  'everest_kasuri_methi',
#  'everest_meat_masala',
#  'everest_turmeric',
#  'figaro',
#  'flote_biene',
#  'frisch_voll_milch',
#  'gala',
#  'garbge_bag',
#  'glade',
#  'godrej_chicken_chilli_salami',
#  'godrej_chicken_italian_sausages',
#  'godrej_easy',
#  'godrej_easy_1',
#  'godrej_rich_cream',
#  'golden_harvest_coriander_powder',
#  'golden_harvest_coriender',
#  'golden_harvest_coriender_powder',
#  'golden_harvest_furtuna',
#  'golden_harvest_red_chili',
#  'good_day_biscuit',
#  'green_tea',
#  'hair_and_care',
#  'haldiram_fried_peanuts',
#  'hand_santitizer',
#  'hersheys_kisses',
#  'hersheys_syrup',
#  'hersheys_syrup_1',
#  'hide_and_seek',
#  'himalaya_baby_lotion',
#  'himalaya_baby_lotion_1',
#  'himalaya_baby_wipes',
#  'himalaya_pure_hands',
#  'horlicks',
#  'id_rice_rawa',
#  'indulekha',
#  'jacobs',
#  'kara_refresh_wipes',
#  'kelogs_choco_fils',
#  'kelogs_choco_fils_2',
#  'kinder_joy',
#  'kissan_tomato',
#  'knoblauch_sauce',
#  'knor',
#  'knor_mixed_vegetable',
#  'knowblauch_sauce_pink',
#  'lord_nelson',
#  'loreal_paris',
#  'loreal_paris_2',
#  'lucky_sugar',
#  'maggi_bangkok',
#  'magnum_icecream',
#  'margo',
#  'mayo',
#  'Milano_1',
#  'milano_2',
#  'milkymist_fruit',
#  'milky_mist_ghee',
#  'more_sago',
#  'mozo',
#  'mr_magic_handwash',
#  'mtr_chilli_powder',
#  'mtr_turmeric',
#  'namdhari_jeera',
#  'nescafe_sunrise',
#  'organic_suji',
#  'pepsodent',
#  'ponds',
#  'ponds_1',
#  'quaker_oats',
#  'red_label_nature_care',
#  'roasted_vermicelli',
#  'rorito',
#  'sabudana',
#  'safal_frozen_sweet_corn',
#  'safolla_gold',
#  'safolla_masala_oats_coriander',
#  'safolla_masala_oats_yellow',
#  'safolla_oats',
#  'salt_alp',
#  'schaschlik_sauce',
#  'sensodyne',
#  'septoplast',
#  'shashlik_sauce',
#  'small_sago',
#  'snickers_cashew',
#  'snickers_original',
#  'soulful_ragi_bites',
#  'special_garam_masala',
#  'sunfeast_marie_lite',
#  'surf_excel',
#  'tajmahal',
#  'tata_salt',
#  'tide',
#  'urad_dal',
#  'vanish',
#  'vaseline',
#  'vaseline_1',
#  'vlcc_dandruff_control',
#  'vlcc_dandruff_ontrol_1',
#  'vlcc_wild_turmeric',
#  'vlcc_wild_turmeric_1',
#  'weikfield_custard',
#  'whiper_extra_long',
#  'whisper_ultraclean',
#  'whole_masoor']

# %%
#method 1 to create a CSV : now we will make a CSV file to have the GCP path and the label

# %%
dataframe=pd.DataFrame(data_array)
dataframe.to_csv('demo_data.csv')

# %%
# Out:
# ['aachi_sambar_powder',
#  'amul_butter',
#  'amul_rasin_and_almond',
#  'banana_chips',
#  'basmati_rice',
#  'bingo',
#  'britania_toast',
#  'cake_box',
#  'catch_hing',
#  'cat_toothpaste',
#  'chicken_nuggets',
#  'chings_schezwan',
#  'chings_veggie_twist',
#  'cleanmate',
#  'coffee_packet',
#  'complan',
#  'corn_packet',
#  'data',
#  'doublemint',
#  'dove',
#  'eastern_meat_masala',
#  'eastern_sambar_powder',
#  'eastern_super_garam_masala',
#  'ektaa_chidwa',
#  'elkos_body',
#  'everest_kasuri_methi',
#  'everest_meat_masala',
#  'everest_turmeric',
#  'figaro',
#  'flote_biene',
#  'frisch_voll_milch',
#  'gala',
#  'garbge_bag',
#  'glade',
#  'godrej_chicken_chilli_salami',
#  'godrej_chicken_italian_sausages',
#  'golden_harvest_coriander_powder',
#  'golden_harvest_furtuna',
#  'golden_harvest_red_chili',
#  'good_day_biscuit',
#  'green_tea',
#  'haldiram_fried_peanuts',
#  'hand_santitizer',
#  'hersheys_kisses',
#  'hide_and_seek',
#  'himalaya_baby_wipes',
#  'horlicks',
#  'id_rice_rawa',
#  'jacobs',
#  'kara_refresh_wipes',
#  'kinder_joy',
#  'kissan_tomato',
#  'knoblauch_sauce',
#  'knor',
#  'knor_mixed_vegetable',
#  'knowblauch_sauce_pink',
#  'lord_nelson',
#  'lucky_sugar',
#  'maggi_bangkok',
#  'magnum_icecream',
#  'margo',
#  'mayo',
#  'milkymist_fruit',
#  'milky_mist_ghee',
#  'more_sago',
#  'mozo',
#  'mr_magic_handwash',
#  'mtr_chilli_powder',
#  'mtr_turmeric',
#  'namdhari_jeera',
#  'nescafe_sunrise',
#  'organic_suji',
#  'pepsodent',
#  'quaker_oats',
#  'red_label_nature_care',
#  'roasted_vermicelli',
#  'rorito',
#  'sabudana',
#  'safal_frozen_sweet_corn',
#  'safolla_gold',
#  'safolla_masala_oats_coriander',
#  'safolla_masala_oats_yellow',
#  'safolla_oats',
#  'salt_alp',
#  'schaschlik_sauce',
#  'sensodyne',
#  'septoplast',
#  'shashlik_sauce',
#  'small_sago',
#  'snickers_cashew',
#  'snickers_original',
#  'soulful_ragi_bites',
#  'special_garam_masala',
#  'sunfeast_marie_lite',
#  'surf_excel',
#  'tajmahal',
#  'tata_salt',
#  'tide',
#  'urad_dal',
#  'vanish',
#  'weikfield_custard',
#  'whiper_extra_long',
#  'whisper_ultraclean',
#  'whole_masoor']
